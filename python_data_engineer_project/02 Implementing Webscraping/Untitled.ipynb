# %%
#

# %%
url = "https://utahavalanchecenter.org/"

# %%
import re
from urllib import robotparser
from urllib.parse import urljoin

import requests



def download(url, num_retries=2, user_agent='wswp', proxies=None):
    """ Download a given URL and return the page content
        args:
            url (str): URL
        kwargs:
            user_agent (str): user agent (default: wswp)
            proxies (dict): proxy dict w/ keys 'http' and 'https', values
                            are strs (i.e. 'http(s)://IP') (default: None)
            num_retries (int): # of retries if a 5xx error is seen (default: 2)
    """
    print('Downloading:', url)
    headers = {'User-Agent': user_agent}
    try:
        resp = requests.get(url, headers=headers, proxies=proxies)
        html = resp.text
        if resp.status_code >= 400:
            print('Download error:', resp.text)
            html = None
            if num_retries and 500 <= resp.status_code < 600:
                # recursively retry 5xx HTTP errors
                return download(url, num_retries - 1)
    except requests.exceptions.RequestException as e:
        print('Download error:', e)
        html = None
    return html


download(url)
# Out:
# Downloading: https://utahavalanchecenter.org/
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n<title>Home - Utah Avalanche Center</title>\n<meta name="viewport" content="width=device-width, initial-scale=1.0">             \n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<link rel="canonical" href="/home" />\n<link rel="shortlink" href="/node/13628" />\n<link rel="shortcut icon" href="https://utahavalanchecenter.org/sites/default/files/images/uac-site/uac-favicon.png" type="image/png" />\n<style type="text/css" media="all">\n@import url("https://utahavalanchecenter.org/modules/system/system.base.css?s9hf5q");\n@import url("https://utahavalanchecenter.org/modules/system/system.menus.css?s9hf5q");\n@import url("https://utahavalanchecenter.org/modules/system/system.messages.css?s9hf5q");\n@import url("https://utahavalanchecenter.org/modules/system/system.theme.css?s9hf5q");\n</style>\n<style type="text/css" media="all">\n@import url("https://utahavalanchecenter.org/sites/all/modules/contrib/jquery_update/replace/ui/themes/base/minified/jquery.ui.core.min.css?s9hf5q");\n@import url("https://utahavalanchecenter.org/sites/all/modules/contrib/jquery_update/replace/ui/themes/base/minified/jquery.ui.theme.min.css?s9hf5q");\n@import url("https://utahavalanchecenter.org/sites/all/modules/contrib/jquery_update/replace/ui/themes/base/minified/jquery.ui.datepicker.min.css?s9hf5q");\n</style>\n<style type="text/css" media="all">\n@import url("https://utahavalanchecenter.org/modules/comment/comment.css?s9hf5q");\n@import url("https://utahavalanchecenter.org/sites/all/modules/contrib/date/date_repeat_field/date_repeat_field.css?s9hf5q");\n@import url("https://utahavalanchecenter.org/modules/field/theme/field.css?s9hf5q");\n@import url("https://utahavalanchecenter.org/modules/node/node.css?s9hf5q");\n@import url("https://utahavalanchecenter.org/modules/search/search.css?s9hf5q");\n@import url("https://utahavalanchecenter.org/modules/user/user.css?s9hf5q");\n@import url("https://utahavalanchecenter.org/sites/all/modules/contrib/views/css/views.css?s9hf5q");\n@import url("https://utahavalanchecenter.org/sites/all/modules/contrib/ckeditor/css/ckeditor.css?s9hf5q");\n</style>\n<style type="text/css" media="all">\n@import url("https://utahavalanchecenter.org/sites/all/modules/contrib/ctools/css/ctools.css?s9hf5q");\n</style>\n<style type="text/css" media="all">\n@import url("https://utahavalanchecenter.org/sites/all/themes/custom/basscss/css/uac.css?s9hf5q");\n@import url("https://utahavalanchecenter.org/sites/all/themes/custom/basscss/css/override.css?s9hf5q");\n@import url("https://utahavalanchecenter.org/sites/all/themes/custom/basscss/dist/style.css?s9hf5q");\n</style>\n<script type="text/javascript" src="https://utahavalanchecenter.org/sites/default/files/js/js_s7yA-hwRxnKty__ED6DuqmTMKG39xvpRyrtyCrbWH4M.js"></script>\n<script type="text/javascript" src="https://utahavalanchecenter.org/sites/default/files/js/js_F1KYEgkeM9FLD2FCMZdSzbO6PJJ47pF6KrY4Aj2djPs.js"></script>\n<script type="text/javascript" src="https://utahavalanchecenter.org/sites/default/files/js/js_1vCIhNpLyxVxI2eDwwTsimBrGE2bbXeB1Jiobpqmlzs.js"></script>\n<script type="text/javascript" src="https://utahavalanchecenter.org/sites/default/files/js/js_xSDJrIqzKxlUgKiqg4buju5b_a5Ui7vWkHQNeKFF1_Q.js"></script>\n<script type="text/javascript" src="https://www.googletagmanager.com/gtag/js?id=UA-6029833-3"></script>\n<script type="text/javascript">\n<!--//--><![CDATA[//><!--\nwindow.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments)};gtag("js", new Date());gtag("set", "developer_id.dMDhkMT", true);gtag("config", "UA-6029833-3", {"groups":"default"});gtag("config", "G-Z63BZHJ9E4", {"groups":"default"});\n//--><!]]>\n</script>\n<script type="text/javascript" src="https://utahavalanchecenter.org/sites/default/files/js/js_uSiDgY_UavWich3xAZ7b3u1PVO3M2kK3ftdF-LXtlmY.js"></script>\n<script type="text/javascript" src="https://utahavalanchecenter.org/sites/default/files/js/js_9cYW8BEU6CFt3ZAVO46Ztf ...

# %%
def get_robots_parser(robots_url):
    " Return the robots parser object using the robots_url "
    rp = robotparser.RobotFileParser()
    rp.set_url(robots_url)
    rp.read()
    return rp

# %%
get_robots_parser(url)

# %%
def get_links(html):
    """ Return a list of links (using simple regex matching)
        from the html content """
    # a regular expression to extract all links from the webpage
    webpage_regex = re.compile("""<a[^>]+href=["'](.*?)["']""", re.IGNORECASE)
    # list of all links from the webpage
    return webpage_regex.findall(html)

get_links("url")
# Out:
# []
